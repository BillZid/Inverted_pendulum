# %%
# 绘制收敛曲线
import matplotlib.pyplot as plt
with open('results/DiscreteQIteration_th-500_dth-500_a-3/result.txt', 'r') as f:
    lines = f.readlines()
    deltas = []
    for line in lines:
        if line[0] == 'e':
            deltas.append(float(line.split(' ')[-1]))
# 绘制50迭代后的收敛曲线，横坐标为迭代次数，纵坐标为delta
# x = range(50, len(deltas))
# plt.plot(x, deltas[50:])
plt.plot(deltas)
plt.xlabel('Iteration')
plt.ylabel('Delta')
plt.show()

# %%
# 绘制Q矩阵热力图
import numpy as np
import seaborn as sns
# q是一个三维数组，第一维是theta，第二维是dtheta，第三维是action
q = np.load('results/QLearning_th-300_dth-300_a-3/checkpoint.npy')
# 选取theta和dtheta的范围
q = q[0:300, 0:300, :]
# 用绘制7个热力图
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
for i in range(3):
    sns.heatmap(q[:, :, i], ax=axes[i], cmap='Blues')
# 横纵坐标轴上的数字不需要显示
axes[0].set_yticklabels([])
axes[0].set_xticklabels([])
axes[1].set_yticklabels([])
axes[1].set_xticklabels([])
axes[2].set_yticklabels([])
axes[2].set_xticklabels([])
# 热力图不显示坐标轴
axes[0].set_axis_off()
axes[1].set_axis_off()
axes[2].set_axis_off()
# 热力图不显示颜色盘
axes[0].collections[0].colorbar.remove()
axes[1].collections[0].colorbar.remove()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
return_list = np.load("./results/DQN/return_list.npy")
# 设置比例为16:9
plt.figure(figsize=(8, 6))
plt.plot(return_list)
plt.xlabel('Episode')
plt.ylabel('Return')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
with open('results/QLearning_th-300_dth-300_a-3/results.txt', 'r') as f:
    lines = f.readlines()
    returns = []
    for line in lines:
        if line[0] == 'e':
            returns.append(float(line.split(' ')[-1]))

plt.plot(returns)
plt.xlabel('Iteration')
plt.ylabel('Return')
# 横坐标轴刻度乘10
plt.xticks(np.arange(0, len(returns), 10), np.arange(0, len(returns), 10) * 10)
plt.show()
